# %% [markdown]
# <a href="https://colab.research.google.com/github/lokixrizz/Ultimatrix/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

display(df_train.head())
display(df_test.head())
print(df_train.info())
print(df_test.info())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
for col in ['GrLivArea', 'BedroomAbvGr', 'FullBath']:
    missing_train = df_train[col].isnull().sum()
    missing_test = df_test[col].isnull().sum() if col in df_test.columns else 0 # Handle potential KeyError
    print(f"Missing values in {col}: Train - {missing_train}, Test - {missing_test}")

def treat_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)
    return df

for col in ['GrLivArea', 'BedroomAbvGr', 'FullBath']:
    df_train = treat_outliers(df_train, col)
    if col in df_test.columns:
        df_test = treat_outliers(df_test, col)

for col in ['GrLivArea', 'BedroomAbvGr', 'FullBath', 'SalePrice']:
    if col in df_train.columns:
        print(f"Data type of {col} in df_train: {df_train[col].dtype}")
        if df_train[col].dtype != 'int64' and df_train[col].dtype != 'float64':
             df_train[col] = pd.to_numeric(df_train[col], errors='coerce')
    if col in df_test.columns:
        print(f"Data type of {col} in df_test: {df_test[col].dtype}")
        if df_test[col].dtype != 'int64' and df_test[col].dtype != 'float64':
            df_test[col] = pd.to_numeric(df_test[col], errors='coerce')
# Out:
# Missing values in GrLivArea: Train - 0, Test - 0
# Missing values in BedroomAbvGr: Train - 0, Test - 0
# Missing values in FullBath: Train - 0, Test - 0
# Data type of GrLivArea in df_train: float64
# Data type of GrLivArea in df_test: float64
# Data type of BedroomAbvGr in df_train: float64
# Data type of BedroomAbvGr in df_test: float64
# Data type of FullBath in df_train: int64
# Data type of FullBath in df_test: float64
# Data type of SalePrice in df_train: int64

# %%
df_train['BedroomBathInteraction'] = df_train['BedroomAbvGr'] * df_train['FullBath']
df_test['BedroomBathInteraction'] = df_test['BedroomAbvGr'] * df_test['FullBath']

relevant_cols = ['GrLivArea', 'BedroomAbvGr', 'FullBath', 'SalePrice', 'BedroomBathInteraction']

for col in relevant_cols:
    if col in df_train.columns:
        if not pd.api.types.is_numeric_dtype(df_train[col]):
            print(f"Converting column '{col}' in df_train to numeric")
            df_train[col] = pd.to_numeric(df_train[col], errors='coerce')
    if col in df_test.columns:
        if not pd.api.types.is_numeric_dtype(df_test[col]):
            print(f"Converting column '{col}' in df_test to numeric")
            df_test[col] = pd.to_numeric(df_test[col], errors='coerce')

# %%
import numpy as np

X = df_train[['GrLivArea', 'BedroomAbvGr', 'FullBath', 'BedroomBathInteraction']]
y = df_train['SalePrice']

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (1460, 4)
# Shape of y: (1460,)

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

y_pred = model.predict(X)

r2 = r2_score(y, y_pred)
print(f"R-squared: {r2}")

mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error (MSE): {mse}")

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# R-squared: 0.5805453365223332
# Mean Squared Error (MSE): 2645411883.6924806
# Root Mean Squared Error (RMSE): 51433.56767416082

# %%
X_test = df_test[['GrLivArea', 'BedroomAbvGr', 'FullBath', 'BedroomBathInteraction']]

y_pred_test = model.predict(X_test)

print(y_pred_test)
# Out:
# [115710.18325734 140157.82159044 203819.46868283 ...  97868.24481307
#   95624.99589405 249840.85679804]
